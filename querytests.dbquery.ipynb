-- %%
SELECT * FROM patient_data.bronze_patient_vitals.patient_vitals;

SELECT * FROM patient_data.silver_patient_vitals.patient_vitals_cleaned;

SELECT * FROM patient_data.gold_patient_vitals.patient_exercise_summary
